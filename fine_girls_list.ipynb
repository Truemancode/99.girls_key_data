# %%
fine_girls_list_all = [
    ["44984429","天使ゆず","---","44984429","satomi0306","ゆず","ファイン"] ,
    ["45045261","百田さき","---","45045261","k3135k1206","さき","ファイン"] ,
    ["45098242","宮内えま","---","45098242","maaya3218","","ファイン"] ,
    ["45074970","田中ゆうこ","---","45074970","aloha0652","","ファイン"], 
    ["43881670","酒井あゆみ","---","43881670","0112hshs","あゆみ","ファイン"] ,
    ["43159693","城咲るる","---","43159693","7724yyy","るる","ファイン"] ,
    ["44328524","児玉ひまり","---","44328524","levi1225","ひまり","ファイン"], 
    ["45045091","新井まこ","---","45045091","mako0326","まこ","ファイン"] ,
    ["45005534","赤羽まなみ","---","45005534","0000","まなみ","ファイン"] ,
    ["38245301","内田いろは","---","38245301","miyuki1108","いろは","ファイン"], 
    ["44985591","愛内くるみ","---","44985591","aiutikurumi","くるみ","ファイン"], 
    ["42304537","山崎まゆ","---","42304537","misaki0423","まゆ","ファイン"] ,
    ["45055615","与田みずき","---","45055615","koHaru0423","みずき","ファイン"], 
    ["44969916","羽川しの","---","44969916","1112","しの","ファイン"] ,
    ["45036545","川越ふうか","---","45036545","Kiyoka0629","","ファイン"], 
    ["43399903","川栄なみ","---","43399903","Ryoka6139","なみ","ファイン"], 
    ["42854813","白花なつき","---","42854813","k540uso9","なつき","ファイン"],
    ["45112779","河井はるか","---","45112779","Naruki0317","はるか","ファイン"] ,
    ["44996962","白川あすな","---","44996962","08120705","あすな","ファイン"] ,
    ["45078873","凪ちさと","---","45078873","ruru0014","ちさと","ファイン"] ,
    ["45003006","篠宮さつき","---","45003006","0000","さつき","ファイン"] ,
    ["45055281","白鳥もね","---","45055281","okioki77","","ファイン"] ,
    ["45002203","佐々木せりな","---","45002203","semicha22","せりな","ファイン"], 
    ["44970953","浜崎すみれ","---","44970953","1234","すみれ","ファイン"] ,
    ["44983396","宮森ゆう","---","44983396","baitagezen","ゆう","ファイン"], 
    ["45037019","吉永かな","---","45037019","2001soutama","かな","ファイン"], 
    ["44998049","神崎るい","---","44998049","0000","るい","ファイン"] ,
    ["44969610","安西しゅうか","---","44969610","0000","しゅうか","ファイン"], 
    ["45139156","佐山いのり","---","45139156","0000","いのり","ファイン"] ,
    ["45003961","星乃りお","---","45003961","35rin0716","りお","ファイン"] ,
    ["45064029","月乃あかり","---","45064029","Nissy723","あかり","ファイン"], 
    ["44965878","佐伯ゆあ","---","44965878","123456789","ゆあ","ファイン"] ,
    ["45037813","成海ゆうか","---","45037813","24248484","ゆうか","ファイン"], 
    ["45000402","樋口ゆりあ","---","45000402","LaLa0426","ゆりあ","ファイン"] ,
    ["45037618","和泉りん","---","45037618","0212","りん","ファイン"] ,
    ["45236219","君乃こねこ","---","45236219","0721","こねこ","ファイン"], 
    ["45074641","一色かんな","---","45074641","0000000000","かんな","ファイン"], 
    ["45064202","天海しおり","---","45064202","fineshiori2","しおり","ファイン"], 
    ["45044738","横原ひめか","---","45044738","nene0804","ひめか","ファイン"] ,
    ["44969915","永島あいな","---","44969915","aina3232","あいな","ファイン"] ,
    ["44997318","夢乃このは","---","44997318","1234","このは","ファイン"] ,
    ["45015962","黒木ゆずは","---","45015962","0000","ゆずは","ファイン"] ,
    ["45052342","桐島れむ","---","45052342","remu3939","れむ","ファイン"] ,
    ["45038120","如月るり","---","45038120","ayaya0413","るり","ファイン"] ,
    ["45064415","榎本のえる","---","45064415","4936","","ファイン"] ,
    ]

# %%
print(len(fine_girls_list_all))
# Out:
# 45

# %%
for x in range(len(fine_girls_list_all)):
    print(f"{x}:" + fine_girls_list_all[x][1])
# Out:
# 0:天使ゆず
# 1:百田さき
# 2:宮内えま
# 3:田中ゆうこ
# 4:酒井あゆみ
# 5:城咲るる
# 6:児玉ひまり
# 7:新井まこ
# 8:赤羽まなみ
# 9:内田いろは
# 10:愛内くるみ
# 11:山崎まゆ
# 12:与田みずき
# 13:羽川しの
# 14:川越ふうか
# 15:川栄なみ
# 16:白花なつき
# 17:河井はるか
# 18:白川あすな
# 19:凪ちさと
# 20:篠宮さつき
# 21:白鳥もね
# 22:佐々木せりな
# 23:浜崎すみれ
# 24:宮森ゆう
# 25:吉永かな
# 26:神崎るい
# 27:安西しゅうか
# 28:佐山いのり
# 29:星乃りお
# 30:月乃あかり
# 31:佐伯ゆあ
# 32:成海ゆうか
# 33:樋口ゆりあ
# 34:和泉りん
# 35:君乃こねこ
# 36:一色かんな
# 37:天海しおり
# 38:横原ひめか
# 39:永島あいな
# 40:夢乃このは
# 41:黒木ゆずは
# 42:桐島れむ
# 43:如月るり
# 44:榎本のえる

# %%
# %store fine_girls_list_all
# Out:
# Stored 'fine_girls_list_all' (list)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# exce_girls_list_all                      -> [['43656794', '氷河', '---', '43656794', 'yuka1108',
# fine_girls_list_all                      -> [['44984429', '天使ゆず', '---', '44984429', 'satomi03
# jenny_girls_list                         -> [['30675586', '比嘉なぎさ', '---', '30675586', 'nagi103
# jenny_girls_list_all                     -> [['36958171', '氷河', '後藤', '36958171', 'yuka1108',
# jenny_girls_list_mygirlonly              -> [['36958171', '氷河', '後藤', '36958171', 'yuka1108',
# jenny_girls_list_subordinate             -> [['40576836', '野波せな', '---', '40576836', 'a980617n
# nuruteka_girls_all                       -> [['44336120', '滝川みこ', '---', '44336120', 'yuka0161
# orekiss_girls_all                        -> [['18894593', 'らん', '---', '18894593', 'ayaka37t',
